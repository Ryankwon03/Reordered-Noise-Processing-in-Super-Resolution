# %%
from PIL import Image
import cv2
import scipy.ndimage 
import numpy as np
from matplotlib import pyplot as plt

# %%
img = Image.open("../../data/original/image3.jpg")
display(img)
print(img.size)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256>
# (256, 256)

# %%
img2 = img.resize((int(img.size[0]/2), int(img.size[1]/2)), Image.Resampling.LANCZOS)
img3 = img2.resize((int(img2.size[0]/2), int(img2.size[1]/2)), Image.Resampling.LANCZOS)
display(img2)
print(img2.size)
display(img3)
print(img3.size)
#img3.save("../../data/downsampled/image3.jpg")
# Out:
# <PIL.Image.Image image mode=RGB size=128x128>
# (128, 128)
# <PIL.Image.Image image mode=RGB size=64x64>
# (64, 64)

# %%
#upsample back to original

img4 = img3.resize((img.size[0], img.size[1]))
display(img4)
print(img4.size)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>
# (256, 256)
