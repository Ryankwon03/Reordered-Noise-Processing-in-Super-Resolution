# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.load('../../results/SR_downsample/downsample_3x256x256x3_1000.npz')
#data = np.load('../../results/SR_noised_downsample/input_3x256x256x3_2000.npz')
print("Keys in the .npz file:", data.files)
# Out:
# Keys in the .npz file: ['arr_0']

# %%
for i in data['arr_0']:
    plt.imshow(i)  # Use 'cmap' if it's a grayscale image
    plt.axis('off')  # Optional: turn off axis
    plt.show()
